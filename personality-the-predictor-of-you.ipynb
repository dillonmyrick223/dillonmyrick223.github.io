# %% [markdown]
# # Introduction
# Personality Psychology is a subject that many have not explored theoretically, but one that we are all students of whether we are aware of it or not; we are constantly discussing how we and those around us act, feel, and think, and this evokes strong feelings and reactions from us, both positive and negative.
#
# Our personality affects everything from the music we like and the interests we pursue, to the habits, dreams, and fears we possess.
#
# For this analysis, I would like to attempt the following:
# 1. Explore various correlations between interests, personality, and demographics
# 2. Estimate Big 5 personality traits by applying labels to each question for the component of personality they measure, using similar questions from validated public tests
# 3. Explore correlations between interests, fears, and other characteristics with Big 5 traits, generate hypotheses, and attempt to predict interests, fears, and happiness using personality traits

# %% [markdown]
# # Survey
#
# In 2013, students in a statistics class at FSEV UK were asked to invite their friends to
# participate in this survey.
#
# The data file (responses.csv) consists of 1010 rows and 150 columns (139 integer and 11 categorical).
# For convenience, the original variable names were shortened in the data file. See the columns.csv file if you want to match the data with the original names.
# The data contain missing values.
# The survey was presented to participants in both electronic and written form.
# The original questionnaire was in Slovak language and was later translated into English.
# All participants were of Slovakian nationality, aged between 15-30.
#
# The variables can be split into the following groups:
#
#    * Music preferences (19 items)
#    * Movie preferences (12 items)
#    * Hobbies & interests (32 items)
#    * Phobias (10 items)
#    * Health habits (3 items)
#    * Personality traits, views on life, & opinions (57 items)
#    * Spending habits (7 items)
#    * Demographics (10 items)
#
# ## Past Research
#
#    (in slovak) Sleziak, P. - Sabo, M.: Gender differences in the prevalence of specific phobias. Forum Statisticum Slovacum. 2014, Vol. 10, No. 6. [Differences (gender + whether people lived in village/town) in the prevalence of phobias.]
#
#    Sabo, Miroslav. Multivariate Statistical Methods with Applications. Diss. Slovak University of Technology in Bratislava, 2014. [Clustering of variables (music preferences, movie preferences, phobias) + Clustering of people w.r.t. their interests.]
#
# ## Questionnaire
# ### Music Preferences
#
#    * **I enjoy listening to music:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I prefer:** *Slow paced music* 1-2-3-4-5 *Fast paced music*
#    * **Dance, Disco, Funk:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Folk music:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Country:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Classical:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Musicals:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Pop:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Rock:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Metal, Hard rock:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Punk:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Hip hop, Rap:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Reggae, Ska:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Swing, Jazz:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Rock n Roll:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Alternative music:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Latin:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Techno, Trance:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Opera:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#
# ### Movie Preferences
#
#    * **I really enjoy watching movies:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **Horror movies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Thriller movies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Comedies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Romantic movies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Sci-fi movies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **War movies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Tales:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Cartoons:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Documentaries:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Western movies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#    * **Action movies:** *Don't enjoy at all* 1-2-3-4-5 *Enjoy very much*
#
# ### Hobbies & Interests
#
#    * **History:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Psychology:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Politics:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Mathematics:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Physics:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Internet:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **PC Software, Hardware:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Economy, Management:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Biology:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Chemistry:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Poetry reading:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Geography:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Foreign languages:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Medicine:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Law:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Cars:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Art:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Religion:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Outdoor activities:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Dancing:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Playing musical instruments:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Poetry writing:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Sport and leisure activities:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Sport at competitive level:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Gardening:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Celebrity lifestyle:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Shopping:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Science and technology:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Theatre:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Socializing:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Adrenaline sports:** *Not interested* 1-2-3-4-5 *Very interested*
#    * **Pets:** *Not interested* 1-2-3-4-5 *Very interested*
#
# ### Phobias
#
#    * **Flying:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Thunder, lightning:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Darkness:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Heights:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Spiders:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Snakes:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Rats, mice:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Ageing:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Dangerous dogs:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#    * **Public speaking:** *Not afraid at all* 1-2-3-4-5 *Very afraid of*
#
# ### Health Habits
#
#    * **Smoking habits:** *Never smoked* - *Tried smoking* - *Former smoker* - *Current smoker*
#    * **Drinking:** *Never* - *Social drinker* - *Drink a lot*
#    * **I live a very healthy lifestyle:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#
# ### Personality Traits, Views On Life & Opinions
#
#    * **I take notice of what goes on around me:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I try to do tasks as soon as possible and not leave them until last minute:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always make a list so I don't forget anything:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I often study or work even in my spare time:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I look at things from all different angles before I go ahead:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I believe that bad people will suffer one day and good people will be rewarded:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I am reliable at work and always complete all tasks given to me:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always keep my promises:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I can fall for someone very quickly and then completely lose interest:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I would rather have lots of friends than lots of money:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always try to be the funniest one:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I can be two faced sometimes:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I damaged things in the past when angry:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I take my time to make decisions:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always try to vote in elections:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I often think about and regret the decisions I make:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I can tell if people listen to me or not when I talk to them:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I am a hypochondriac:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I am emphatetic person:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I eat because I have to. I don't enjoy food and eat as fast as I can:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I try to give as much as I can to other people at Christmas:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I don't like seeing animals suffering:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I look after things I have borrowed from others:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I feel lonely in life:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I used to cheat at school:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I worry about my health:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I wish I could change the past because of the things I have done:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I believe in God:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always have good dreams:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always give to charity:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I have lots of friends:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **Timekeeping:** *I am often early.* - *I am always on time.* - *I am often running late.*
#    * **Do you lie to others?:** *Never.* - *Only to avoid hurting someone.* - *Sometimes.* - *Everytime it suits me.*
#    * **I am very patient:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I can quickly adapt to a new environment:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **My moods change quickly:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I am well mannered and I look after my appearance:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I enjoy meeting new people:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always let other people know about my achievements:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I think carefully before answering any important letters:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I enjoy childrens' company:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I am not afraid to give my opinion if I feel strongly about something:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I can get angry very easily:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always make sure I connect with the right people:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I have to be well prepared before public speaking:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I will find a fault in myself if people don't like me:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I cry when I feel down or things don't go the right way:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I am 100% happy with my life:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I am always full of life and energy:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I prefer big dangerous dogs to smaller, calmer dogs:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I believe all my personality traits are positive:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **If I find something the doesn't belong to me I will hand it in:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I find it very difficult to get up in the morning:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I have many different hobbies and interests:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I always listen to my parents' advice:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I enjoy taking part in surveys:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **How much time do you spend online?:** *No time at all* - *Less than an hour a day* - *Few hours a day* - *Most of the day*
#
# ### Spending Habits
#
#    * **I save all the money I can:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I enjoy going to large shopping centres:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I prefer branded clothing to non branded:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I spend a lot of money on partying and socializing:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I spend a lot of money on my appearance:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I spend a lot of money on gadgets:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#    * **I will hapilly pay more money for good, quality or healthy food:** *Strongly disagree* 1-2-3-4-5 *Strongly agree*
#
# ### Demographics
#
#    * **Age:**
#    * **Height:**
#    * **Weight:**
#    * **How many siblings do you have?:**
#    * **Gender:** *Female* - *Male*
#    * **I am:** *Left handed* - *Right handed*
#    * **Highest education achieved:** *Currently a Primary school pupil* - *Primary school* - *Secondary school* - *College/Bachelor degree*
#    * **I am the only child:** *No* - *Yes*
#    * **I spent most of my childhood in a:** *City* - *village*
#    * **I lived most of my childhood in a:** *house/bungalow* - *block of flats*
#
#
# Dataset page: https://www.kaggle.com/datasets/miroslavsabo/young-people-survey

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go

sns.set()
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

data = pd.read_csv('/kaggle/input/young-people-survey/responses.csv')
data['ID'] = data.index
data.head()

# %%
data.shape

# %% [markdown]
# # Exploratory Analysis

# %%
data.describe(include='all')

# %% [markdown]
# Let's look at a few correlations and start thinking about questions we would like to ask.
#
# We'll start with something basic and intuitive, the correlation between liking fast songs and techno music.

# %%
sns.barplot(x=data['Techno, Trance'], 
            y=data['Slow songs or fast songs'], 
            ci=False).set_title('Preference for Techno/Trance and Fast Music')

plt.show()

# %% [markdown]
# Not surprisingly, many people who like techno/trance music also tend to like faster music.
# Now let's look at preference for romance movies, split by gender.

# %%
sns.barplot(x=data['Gender'], 
            y=data['Romantic'], 
            ci=False).set_title('Preference for Romantic Films by Gender')

plt.show()

# %% [markdown]
# How about the relationship between the preference for friends over money and happiness?

# %%
sns.barplot(x=data['Happiness in life'], 
            y=data['Friends versus money'], 
            ci=False).set_title('Preference for Friends over Money vs. Happiness')

plt.show()

# %% [markdown]
# As you can see, there are many questions we can ask and many angles to explore, which is one of the reasons why I found this dataset so fascinating.
#
# Before we dive in though, let's look at missing values and possible outliers.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# First let's deal with a few obvious outliers. One that stands out is the minimum height of 62cm (2 feet).

# %%
data[data['Height'] < 140]

# %% [markdown]
# Looking at the Age and Weight columns, for a 20 year old woman who weighs 55kg (121 lbs), it seems like the actual value for this entry should be 162cm (5 feet 4 in), so we'll use that value instead.

# %%
data.loc[data['ID'] == 676, 'Height'] = 162.0
data[data['ID'] == 676]

# %% [markdown]
# Another simple check would be making sure the Only child and Number of siblings columns are consistent.

# %%
data[((data['Only child'] == 'yes') & (data['Number of siblings'] > 0))][['Only child', 'Number of siblings']]

# %% [markdown]
# As seen below, the distribution of the number of siblings column is fairly normal, and the average for the column and the average number of children per woman in Slovakia are close, so we will assume the siblings column is accurate and use it to re-populate the only child column.
#
# Let's also fill in the 6 rows missing number of siblings with the mode while we're here.

# %%
print('Average Number of Siblings: ', round(data['Number of siblings'].mean(), 2))
print('Average Number of Children/Woman in Slovakia: 1.45')
sns.displot(data['Number of siblings'])
plt.show()

# %%
data['Number of siblings'].fillna(1, inplace=True)
data['Only child'] = 0
data.loc[data['Number of siblings'] == 0, 'Only child'] = 1

# %%
cat_cols = data.select_dtypes(include='object').columns.to_list()
cont_cols = ['Age', 'Height', 'Weight', 'Number of siblings', 'ID']
non_ord_cols = cont_cols + cat_cols
ord_cols = data.drop(columns=non_ord_cols).columns.to_list()
data[ord_cols].head(1)

# %%
pd.options.display.max_rows = 200
data.isnull().sum()

# %% [markdown]
# Fortunately there are not too many missing values, but we still need to deal with the ones we have.
#
# We could drop the rows with missing values, but it would be unfortunate to lose all the information contained in the other columns just for a few missing values, so let's impute values instead. We could simply use the mean for this, but I'd like to try to find a way that better estimates the values. Let's try and find along what lines values tend to differ the most, and impute estimations for those groups.

# %% [markdown]
# Let's start with the categorical columns first since there are fewer of them, and may be easier to deal with if they contain mostly one value.

# %%
cat_cols = data.select_dtypes(include='object').columns.tolist()
data[cat_cols].head()

# %%
for i in cat_cols:
    print(i)
    print(data[i].value_counts(normalize=True))
    print()

# %% [markdown]
# For Smoking, Alcohol, Lying, Punctuality, and Left - right handed, let's impute the mode.

# %%
data['Left - right handed'].fillna('right handed', inplace=True)
data['Smoking'].fillna('tried smoking', inplace=True)
data['Alcohol'].fillna('social drinker', inplace=True)
data['Lying'].fillna('sometimes', inplace=True)
data['Punctuality'].fillna('i am always on time', inplace=True)

# %% [markdown]
# Now let's move on to gender. As we know, males tend to on average be taller and weigh more than females, as seen below:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.histplot(data=data, x='Weight', hue='Gender', ax=axes[0]).set_title('Weight')
sns.histplot(data=data, x='Height', hue='Gender', ax=axes[1]).set_title('Height')
plt.show()

# %% [markdown]
# We also know that age has an effect for this age group:

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

ax = sns.scatterplot(x=data['Age'], y=data['Weight'], hue=data['Gender'], ax=axes[0]).set_title('Age x Weight')
ax = sns.scatterplot(x=data['Age'], y=data['Height'], hue=data['Gender'], ax=axes[1]).set_title('Age x Height')

plt.show()

# %% [markdown]
# Using this information, we can create weight and height dictionaries that contain the averages for each age, separated by gender. We will then use this to compare the weight and height of rows where gender is null to the averages for that row's age, and impute the gender that the height and weight most closely match.

# %%
female_age_weight_dict = {}
male_age_weight_dict = {}
female_age_height_dict = {}
male_age_height_dict = {}

for i in data[data['Gender'] == 'female']['Age'].unique():
    female_age_height_dict[i] = data.loc[(data['Age'] == i) & (data['Gender'] == 'female'), 'Height'].mean()
    female_age_weight_dict[i] = data.loc[(data['Age'] == i) & (data['Gender'] == 'female'), 'Weight'].mean()

for i in data[data['Gender'] == 'male']['Age'].unique():
    male_age_height_dict[i] = data.loc[(data['Age'] == i) & (data['Gender'] == 'male'), 'Height'].mean()
    male_age_weight_dict[i] = data.loc[(data['Age'] == i) & (data['Gender'] == 'male'), 'Weight'].mean()

for i in data.loc[(data['Gender'].isnull()) & (data['Weight'].notnull())]['ID']:
    male_height_diff = abs(data.loc[data['ID'] == i, 'Height'].values[0] - male_age_height_dict[data.loc[data['ID'] == i, 'Age'].values[0]])
    male_weight_diff = abs(data.loc[data['ID'] == i, 'Weight'].values[0] - male_age_weight_dict[data.loc[data['ID'] == i, 'Age'].values[0]])
    female_height_diff = abs(data.loc[data['ID'] == i, 'Height'].values[0] - female_age_height_dict[data.loc[data['ID'] == i, 'Age'].values[0]])
    female_weight_diff = abs(data.loc[data['ID'] == i, 'Weight'].values[0] - female_age_weight_dict[data.loc[data['ID'] == i, 'Age'].values[0]])
    if (male_height_diff < female_height_diff) & (male_weight_diff < female_weight_diff):
        data.loc[data['ID'] == i, 'Gender'] = 'male'
    if (female_height_diff < male_height_diff) & (female_weight_diff < male_weight_diff):
        data.loc[data['ID'] == i, 'Gender'] = 'female'
        
data[data['ID'].isin([137,201,226,542,621,934])][['Gender', 'Height', 'Weight', 'Age']]

# %% [markdown]
# It looks like we were able to take care of all but two null rows for gender. The first has null values for height and weight, so not much can be done there. The other is an exception to our logic above, with the height being closer to the average man of the same age and the weight being similar to the average woman of the same age.
#
# Looking at the distributions of height and weight above, while it is more likely for a woman to weigh 65kg than a man, it is much more likely for a man to be 183cm than a woman, so while it is a bit arbitrary we will use male for this row.

# %%
data.loc[data['ID'] == 621, 'Gender'] = 'male'

# %% [markdown]
# For Education, we only have one row with a null value:

# %%
data[data['Education'].isnull()]

# %% [markdown]
# After reading about education in Slovakia, I found that the typical age of someone in their last year of primary school is 14-15, and is 18-19 for secondary school, so we'll use secondary school to fill in the null value.

# %%
data.loc[data['ID'] == 831, 'Education'] = 'secondary school'

# %% [markdown]
# Now let's look at Village - town and House - block of flats.
#
# If you thought there might be a relationship between these variables, you were correct. As you can see below, someone living in the city is much more likely to live in a block of flats than a house, while the opposite is true for those who love in a village.

# %%
sns.countplot(x=data['Village - town'], hue=data['House - block of flats'])
plt.show()

# %% [markdown]
# Let's use this information to impute values for both variables.

# %%
data.loc[(data['Village - town'].isnull()) & (data['House - block of flats'] == 'block of flats'), 'Village - town'] = 'city'
data.loc[(data['Village - town'].isnull()) & (data['House - block of flats'] == 'house/bungalow'), 'Village - town'] = 'village'
data.loc[(data['House - block of flats'].isnull()) & (data['Village - town'] == 'city'), 'House - block of flats'] = 'block of flats'
data.loc[(data['House - block of flats'].isnull()) & (data['Village - town'] == 'village'), 'House - block of flats'] = 'house/bungalow'

# %% [markdown]
# Next let's look at rows where either Weight, Height, or Age is null.

# %%
data.loc[(data['Height'].isnull()) | (data['Weight'].isnull()) | (data['Age'].isnull())][['Age', 'Weight', 'Height', 'Gender']]

# %% [markdown]
# Similar to before, if we know the Age and Gender for a row, then we can use those columns to estimate the null values for Height and Weight, using the dictionaries we created earlier.

# %%
for i in data.loc[(data['Weight'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'male')]['ID']:
    data.loc[data['ID'] == i, 'Weight'] = male_age_weight_dict[data.loc[data['ID'] == i, 'Age'].values[0]]
    
for i in data.loc[(data['Height'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'male')]['ID']:
    data.loc[data['ID'] == i, 'Height'] = male_age_height_dict[data.loc[data['ID'] == i, 'Age'].values[0]]    
    
for i in data.loc[(data['Weight'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'female')]['ID']:
    data.loc[data['ID'] == i, 'Weight'] = female_age_weight_dict[data.loc[data['ID'] == i, 'Age'].values[0]]
    
for i in data.loc[(data['Height'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'female')]['ID']:
    data.loc[data['ID'] == i, 'Height'] = female_age_height_dict[data.loc[data['ID'] == i, 'Age'].values[0]]  
    
data.loc[(data['Height'].isnull()) | (data['Weight'].isnull()) | (data['Age'].isnull())][['Age', 'Weight', 'Height', 'Gender']]

# %% [markdown]
# We can also estimate missing Age values by using the Education column. If the rows with missing age values have an Education value, we can use the median value for that education level to impute values.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.countplot(x=data[data['Education'] == 'masters degree']['Age'], ax=axes[1])
sns.countplot(x=data[data['Education'] == 'college/bachelor degree']['Age'], ax=axes[0])
axes[0].set_xticklabels(range(16,30))
axes[1].set_xticklabels(range(19,31))
plt.show()

# %%
data.loc[(data['Age'].isnull()) & (data['Education'] == 'college/bachelor degree'), 'Age'] = 21
data.loc[(data['Age'].isnull()) & (data['Education'] == 'masters degree'), 'Age'] = 26

for i in data.loc[(data['Weight'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'male')]['ID']:
    data.loc[data['ID'] == i, 'Weight'] = male_age_weight_dict[data.loc[data['ID'] == i, 'Age'].values[0]]
    
for i in data.loc[(data['Height'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'male')]['ID']:
    data.loc[data['ID'] == i, 'Height'] = male_age_height_dict[data.loc[data['ID'] == i, 'Age'].values[0]]    
    
for i in data.loc[(data['Weight'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'female')]['ID']:
    data.loc[data['ID'] == i, 'Weight'] = female_age_weight_dict[data.loc[data['ID'] == i, 'Age'].values[0]]
    
for i in data.loc[(data['Height'].isnull()) & (data['Age'].notnull()) & (data['Gender'] == 'female')]['ID']:
    data.loc[data['ID'] == i, 'Height'] = female_age_height_dict[data.loc[data['ID'] == i, 'Age'].values[0]]  
    
data.loc[(data['Height'].isnull()) | (data['Weight'].isnull()) | (data['Age'].isnull())][['Age', 'Weight', 'Height', 'Gender']]

# %% [markdown]
# Now the only remaining columns we haven't dealt with are the non-categorical main survey questions. We could simply impute the average for these, or the average along a certain dimension like age or gender, but an arguably better way to do this would be to use KNNImputer, which uses the nearest neighbors algorithm to impute the mean of n nearest neighbors for missing values.
#
# An easy rule of thumb for what to use for K is the square root of the number of samples in the dataset, so in our case K = 32.

# %%
cont_cols = ['Age', 'Height', 'Weight', 'Number of siblings', 'ID']
non_ord_cols = cont_cols + cat_cols
ord_cols = data.drop(columns=non_ord_cols).columns.to_list()

data[data['Passive sport'].isnull()].head()

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=32, weights='distance')

cont_cols = ['Age', 'Height', 'Weight', 'Number of siblings', 'ID']
non_ord_cols = cont_cols + cat_cols
ord_cols = data.drop(columns=non_ord_cols).columns.to_list()

data[ord_cols] = imputer.fit_transform(data[ord_cols]).round(0)

# %%
print(len(data))
print(len(data.dropna()))

# %% [markdown]
# Now we have reduced the number of rows with missing values to just 2 entries. Since this is such a small number we'll go ahead and drop these.

# %%
data.dropna(inplace=True)

# %% [markdown]
# Now we are finished cleaning up our data. Next, we'll determine the Big 5 personality traits for each person in the survey.
#
# Typically this would necesitate that each person had taken a Big 5 test. However, several of the questions in the personality section map very well to questions used in Big 5 tests. I referenced publicly available Big 5 questions and scoring methods, and mapped the Big 5 Factor Marker that seemed most appropriate to the questions that seemed equivalent to the questions from the test.
#
# Big 5 Questions: https://ipip.ori.org/newBigFive5broadKey.htm, https://ipip.ori.org/new_ipip-50-item-scale.htm
#
# Scoring Method: https://ipip.ori.org/newScoringInstructions.htm

# %%
cols_big5 = pd.read_csv('/kaggle/input/young-people-survey-columns-with-big-5-markers/Survey Columns with Big 5.csv')
cols_big5[cols_big5['Big 5 Trait'].notnull()]

# %% [markdown]
# # The Big 5 Personality Traits
#
# ## Openness
# Openness to experience is a general appreciation for art, emotion, adventure, unusual ideas, imagination, curiosity, and variety of experience. People who are open to experience are intellectually curious, open to emotion, sensitive to beauty and willing to try new things. They tend to be, when compared to closed people, more creative and more aware of their feelings. They are also more likely to hold unconventional beliefs. High openness can be perceived as unpredictability or lack of focus, and more likely to engage in risky behavior or drug-taking. Moreover, individuals with high openness are said to pursue self-actualization specifically by seeking out intense, euphoric experiences.
#
# Conversely, those with low openness seek to gain fulfillment through perseverance and are characterized as pragmatic and data-driven – sometimes even perceived to be dogmatic and closed-minded. Some disagreement remains about how to interpret and contextualize the openness factor as there is a lack of biological support for this particular trait. Openness has not shown a significant association with any brain regions as opposed to the other four traits which did when using brain imaging to detect changes in volume associated with each trait
#
# ## Conscientiousness
# Conscientiousness is a tendency to display self-discipline, act dutifully, and strive for achievement against measures or outside expectations. It is related to the way in which people control, regulate, and direct their impulses. High conscientiousness is often perceived as being stubborn and focused. Low conscientiousness is associated with flexibility and spontaneity, but can also appear as sloppiness and lack of reliability. High scores on conscientiousness indicate a preference for planned rather than spontaneous behavior.
#
# ## Extraversion
# Extraversion is characterized by breadth of activities (as opposed to depth), surgency from external activity/situations, and energy creation from external means. The trait is marked by pronounced engagement with the external world. Extraverts enjoy interacting with people, and are often perceived as full of energy. They tend to be enthusiastic, action-oriented individuals. They possess high group visibility, like to talk, and assert themselves. Extraverted people may appear more dominant in social settings, as opposed to introverted people in this setting.
#
# Introverts have lower social engagement and energy levels than extraverts. They tend to seem quiet, low-key, deliberate, and less involved in the social world. Their lack of social involvement should not be interpreted as shyness or depression; instead they are more independent of their social world than extraverts. Introverts need less stimulation, and more time alone than extraverts. This does not mean that they are unfriendly or antisocial; rather, they are reserved in social situations
#
# ## Agreeableness
# The agreeableness trait reflects individual differences in general concern for social harmony. Agreeable individuals value getting along with others. They are generally considerate, kind, generous, trusting and trustworthy, helpful, and willing to compromise their interests with others. Agreeable people also have an optimistic view of human nature.
#
# Disagreeable individuals place self-interest above getting along with others. They are generally unconcerned with others' well-being and are less likely to extend themselves for other people. Sometimes their skepticism about others' motives causes them to be suspicious, unfriendly, and uncooperative. Low agreeableness personalities are often competitive or challenging people, which can be seen as argumentative or untrustworthy.
#
# ## Neuroticism/Emotional Stability
# Neuroticism is the tendency to experience negative emotions, such as anger, anxiety, or depression. It is sometimes called emotional instability, or is reversed and referred to as emotional stability.   Those who score high in neuroticism are emotionally reactive and vulnerable to stress. They are more likely to interpret ordinary situations as threatening. They can perceive minor frustrations as hopelessly difficult. They also tend to be flippant in the way they express emotions. Their negative emotional reactions tend to persist for unusually long periods of time, which means they are often in a bad mood. For instance, neuroticism is connected to a pessimistic approach toward work, to certainty that work impedes personal relationships, and to higher levels of anxiety from the pressures at work. Furthermore, those who score high on neuroticism may display more skin-conductance reactivity than those who score low on neuroticism. These problems in emotional regulation can diminish the ability of a person scoring high on neuroticism to think clearly, make decisions, and cope effectively with stress. Lacking contentment in one's life achievements can correlate with high neuroticism scores and increase one's likelihood of falling into clinical depression. Moreover, individuals high in neuroticism tend to experience more negative life events, but neuroticism also changes in response to positive and negative life experiences. Also, individuals with higher levels of neuroticism tend to have worse psychological well-being.
#
# At the other end of the scale, individuals who score low in neuroticism are less easily upset and are less emotionally reactive. They tend to be calm, emotionally stable, and free from persistent negative feelings. Freedom from negative feelings does not mean that low scorers experience a lot of positive feelings

# %% [markdown]
# Using the scoring method above, let's calculate the percentile of each trait for each entry.

# %%
neg_marker_dict = {5:1, 4:2, 2:4, 1:5}

for t in cols_big5[cols_big5['Big 5 Trait'].notnull()]['Big 5 Trait'].unique():
    d = data[cols_big5[cols_big5['Big 5 Trait'] == t]['Short'].unique()].copy()
    for q in d.columns:
        if cols_big5[cols_big5['Short'] == q]['Big 5 Factor Marker'].str.endswith('-').bool():
            d[q] = d[q].replace(neg_marker_dict)
    
    data[t] = d.sum(axis=1, numeric_only=True)
#     .rank(pct=True)
    
data.head()

# %%
sns.pairplot(data[['Openness', 'Extraversion', 'Conscientiousness', 'Emotional Stability', 'Agreeableness']])
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

original_trait_scores = data[['Openness', 'Extraversion', 'Conscientiousness', 'Emotional Stability', 'Agreeableness']].copy()
data[['Openness', 'Extraversion', 'Conscientiousness', 'Emotional Stability', 'Agreeableness']] = scaler.fit_transform(data[['Openness', 'Extraversion', 'Conscientiousness', 'Emotional Stability', 'Agreeableness']])
    
data.head()

# %% [markdown]
# Now we have our Big 5 Traits!
#
# While there is some mild correlation between Openness and Extraversion, overall the traits are mostly not correlated and normally distributed, which matches what we know about the Big 5 Traits.
#
# Before we use these to make assumptions and predictions, we should try and validate that they accurately measure the traits they represent.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.barplot(x=data['Fear of public speaking'], 
            y=data['Extraversion'], 
            ci=False, ax=axes[0]).set_title('Extraversion and Fear of Public Speaking')

sns.histplot(data=data,
            x='Extraversion', 
            hue='Gender',
            ax=axes[1]).set_title('Extraversion by Gender')

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.barplot(x=data['Dangerous dogs'], 
            y=data['Emotional Stability'], 
            ci=False, ax=axes[0]).set_title('Emotional Stability and Fear of Large Dogs')

sns.histplot(data=data,
            x='Emotional Stability', 
            hue='Gender',
            ax=axes[1]).set_title('Emotional Stability by Gender')

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.barplot(x=data['Happiness in life'], 
            y=data['Agreeableness'], 
            ci=False, ax=axes[0]).set_title('Agreeableness and Happiness')

sns.histplot(data=data,
            x='Agreeableness', 
            hue='Gender',
            ax=axes[1]).set_title('Agreeableness by Gender')

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.barplot(x=data['Finances'], 
            y=data['Conscientiousness'], 
            ci=False, ax=axes[0]).set_title('Conscientiousness and Saving Money')

sns.histplot(data=data,
            x='Conscientiousness', 
            hue='Gender',
            ax=axes[1]).set_title('Conscientiousness by Gender')

plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,5))

sns.barplot(x=data['Fantasy/Fairy tales'], 
            y=data['Openness'], 
            ci=False, ax=axes[0]).set_title('Openness and Interest in Fantasy Movies')

sns.histplot(data=data,
            x='Openness', 
            hue='Gender',
            ax=axes[1]).set_title('Openness by Gender')

plt.show()

# %% [markdown]
# # Data Exploration
# Now, let's create dummy variables for our categorical data, and then explore correlations between our features.

# %%
# Create age categories
label_names = ['18 and Under', '19-24', '25-30']
cut_points =  [0, 18, 24, 30]

data['Age_category'] = pd.cut(data['Age'], cut_points, labels=label_names)
data.head()

# %%
data['BMI'] = data['Weight']/(data['Height'] / 100) ** 2
data['underweight'] = 0
data.loc[data['BMI'] < 18.5, 'underweight'] = 1
data['overweight'] = 0
data.loc[data['BMI'] >= 25.0, 'overweight'] = 1
data.head()

# %%
# Create dummy columns
def create_dummies(df, column_name):
    dummies = pd.get_dummies(df[column_name], prefix = column_name)
    df = pd.concat([df, dummies], axis=1)
    return df
    
data = create_dummies(data, 'Gender')
data = create_dummies(data, 'Age_category')
data = create_dummies(data, 'Village - town')
data = create_dummies(data, 'House - block of flats')
data = create_dummies(data, 'Smoking')
data = create_dummies(data, 'Alcohol')
data = create_dummies(data, 'Education')
data = create_dummies(data, 'Lying')
data = create_dummies(data, 'Internet usage')

data.head()

# %%
music_cols = data.iloc[:, :19].columns.to_list()
movie_cols = data.iloc[:, 19:31].columns.to_list()
interest_cols = data.iloc[:, 31:63].columns.to_list()
fears_cols = data.iloc[:, 63:73].columns.to_list()
health_cols = data.iloc[:, 73:76].columns.to_list()
personality_cols = data.iloc[:, 76:133].columns.to_list()
spending_cols = data.iloc[:, 133:140].columns.to_list()
type_cols = data.iloc[:, 151:156].columns.to_list()

# %% [markdown]
# ## Correlations

# %% [markdown]
# ### Music

# %%
correlations = data[music_cols].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Movies

# %%
correlations = data[movie_cols].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Interests

# %%
correlations = data[interest_cols].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Personality

# %%
correlations = data[personality_cols].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(16,14))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Fears

# %%
correlations = data[fears_cols].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Diet and Alcohol/Smoking

# %%
correlations = data[['Healthy eating', 
                     'Alcohol_never', 
                     'Alcohol_social drinker', 
                     'Alcohol_drink a lot',
                     'Smoking_current smoker',
                     'Smoking_former smoker',
                     'Smoking_never smoked',
                     'Smoking_tried smoking']].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Spending

# %%
correlations = data[spending_cols].corr()
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# ### Demographics

# %%
correlations = data[['Gender_female', 
                     'Gender_male', 
                     'Age_category_18 and Under', 
                     'Age_category_19-24',
                     'Age_category_25-30',
                     'Village - town_city',
                     'Village - town_village',
                     'House - block of flats_block of flats',
                     'House - block of flats_house/bungalow',
                     'Education_currently a primary school pupil',
                     'Education_primary school',
                     'Education_secondary school',
                     'Education_college/bachelor degree',
                     'Education_masters degree',
                     'Education_doctorate degree',
                     'Number of siblings',
                     'Only child',
                     'overweight',
                     'underweight']].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# # Feature Engineering
# Based on some of the correlations we've seen, let's create a few features that summarize shared characteristics of several items in our survey:
# 1. interests_Humanities & Social Sciences
#     * History
#     * Psychology
#     * Politics
#     * Law
#     * Religion
#     * Foreign languages
#
#
# 2. interests_STEM
#     * Mathematics
#     * Physics
#     * Internet
#     * PC Software, Hardware
#     * Biology
#     * Chemistry
#     * Medicine
#     * Science and technology
#
#
# 3. interests_Arts & Literature
#     * Art
#     * Poetry reading
#     * Playing musical instruments
#
#
# 4. interests_Outdoor & Physical Activities
#     * Outdoor activities
#     * Dancing
#     * Sport and leisure activities
#     * Sport at competitive level
#     * Adrenaline sports
#     * Gardening
#
#
# 5. interests_Entertainment & Lifestyle
#     * Celebrity lifestyle
#     * Shopping
#     * Pets
#
#
# 7. fears_Nature & Environment
#     * Flying
#     * Thunder, lightning
#     * Darkness
#     * Heights
#
#
# 8. fears_Animals & Insects
#     * Spiders
#     * Snakes
#     * Rats, mice
#     * Dangerous dogs
#
#
# 9. music_Rhythmic and Energetic:
#     * Hip hop, Rap
#     * Dance
#     * Pop
#
#
# 10. music_Traditional and Roots:
#     * Folk music
#     * Country
#
#
# 11. music_Sophisticated and Classic:
#     * Classical
#     * Opera
#     * Swing, Jazz
#
#
# 12. music_Intense and Powerful:
#     * Rock
#     * Metal, Hard rock
#     * Punk
#
#
# 13. movies_Action:
#     * Action
#     * Sci-fi
#     * War
#     * Western
#
#
# 14. movies_tales:
#     * Fantasy/Fairy tales
#     * Animated
#
#
# 15. movies_thrilling:
#     * Horror
#     * Thriller
#
#
# We will also create interaction variables for each of the Big 5 traits.

# %%
data['interests_Humanities & Social Sciences'] = data['History'] + data['Law'] + data['Psychology'] + data['Politics'] + data['Foreign languages'] + data['Religion']
                    
data['interests_STEM'] = data['Medicine'] + data['Mathematics'] + data['Physics'] + data['Internet'] + data['PC'] + data['Biology'] + data['Chemistry'] + data['Science and technology']
                            
data['interests_Art & Literature'] = data['Art exhibitions'] + data['Reading'] + data['Musical instruments']
                
data['interests_Outdoor & Physical'] = data['Adrenaline sports'] + data['Active sport'] + data['Passive sport'] + data['Dancing'] + data['Countryside, outdoors'] + data['Gardening']
                    
data['interests_Lifestyle & Entertainment'] = data['Celebrities'] + data['Shopping'] + data['Pets']

data['fears_Nature & Environment'] = data['Storm'] + data['Heights'] + data['Darkness'] + data['Flying']
            
data['fears_Animals & Insects'] = data['Rats'] + data['Snakes'] + data['Spiders'] + data['Dangerous dogs']
            
data['music_Rythmic'] = data['Dance'] + data['Hiphop, Rap'] + data['Pop']
            
data['music_Traditional'] = data['Country'] + data['Folk']

data['music_Classic'] = data['Classical music'] + data['Opera'] + data['Swing, Jazz']
        
data['music_Rock'] = data['Rock'] + data['Metal or Hardrock'] + data['Punk']
        
data['movies_Action'] = data['Action'] + data['Sci-fi'] + data['War'] + data['Western']
            
data['movies_Tales'] = data['Fantasy/Fairy tales'] + data['Animated']
    
data['movies_Thrilling'] = data['Horror'] + data['Thriller']
    
# Interaction terms
data['E x O'] = original_trait_scores['Extraversion'] * original_trait_scores['Openness']
data['E x A'] = original_trait_scores['Extraversion'] * original_trait_scores['Agreeableness']
data['E x C'] = original_trait_scores['Extraversion'] * original_trait_scores['Conscientiousness']
data['E x E'] = original_trait_scores['Extraversion'] * original_trait_scores['Emotional Stability']

data['O x A'] = original_trait_scores['Openness'] * original_trait_scores['Agreeableness']
data['O x C'] = original_trait_scores['Openness'] * original_trait_scores['Conscientiousness']
data['O x E'] = original_trait_scores['Openness'] * original_trait_scores['Emotional Stability']

data['A x C'] = original_trait_scores['Agreeableness'] * original_trait_scores['Conscientiousness']
data['A x E'] = original_trait_scores['Agreeableness'] * original_trait_scores['Emotional Stability']

data['C x E'] = original_trait_scores['Conscientiousness'] * original_trait_scores['Emotional Stability']

# %% [markdown]
# # Gender Differences and Trait Correlations
# We also know that gender is a significant predictor of interests. Let's look at the correlations between our variables again, but this time with Gender and Big 5 traits added in.

# %% [markdown]
# ### Differences in Interests by Gender

# %%
g = pd.pivot_table(data=data, columns='Gender', values=interest_cols, aggfunc='mean')
g['difference'] = abs(g['female'] - g['male'])
g.sort_values(by='difference', ascending=False)

# %%
gend_interest = pd.pivot_table(data=data, columns='Gender', values=interest_cols, aggfunc='mean')
gend_interest['gap'] = abs(gend_interest['female'] - gend_interest['male'])
gend_interest.loc[gend_interest['gap'] >= .5, ['female', 'male']].plot(kind='bar')
plt.show()

# %% [markdown]
# We can see that the biggest differences in interests between men and women arise from men's larger interest in things, science/technology, and sports, and women's larger interest in people, art, and fashion.
#
# Now let's re-examine the correlations we looked at earlier, but with gender and Big 5 traits added in.

# %%
correlations = data[music_cols + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness', 'Gender_male', 'Gender_female']].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
correlations = data[movie_cols + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness', 'Gender_male', 'Gender_female']].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
correlations = data[interest_cols + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness', 'Gender_male', 'Gender_female']].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
correlations = data[fears_cols + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness', 'Gender_male', 'Gender_female']].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
correlations = data[['Healthy eating', 
                     'Alcohol_never', 
                     'Alcohol_social drinker', 
                     'Alcohol_drink a lot',
                     'Smoking_current smoker',
                     'Smoking_former smoker',
                     'Smoking_never smoked',
                     'Smoking_tried smoking'] + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness', 'Gender_male', 'Gender_female']].corr()

sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
correlations = data[spending_cols + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness', 'Gender_male', 'Gender_female']].corr()
sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
correlations = data[['Final judgement', 'God', 'Dreams', 
                     'Happiness in life', 'Energy levels',
                     'Self-criticism', 'Changing the past',
                     'Loneliness', 'Empathy', 'Compassion to animals',
                     'Finances', 'Music', 'Movies'] + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness', 'Gender_male', 'Gender_female']].corr()

sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %%
correlations = data[['Gender_female', 
                     'Gender_male', 
                     'Age_category_18 and Under', 
                     'Age_category_19-24',
                     'Age_category_25-30',
                     'Village - town_city',
                     'Village - town_village',
                     'House - block of flats_block of flats',
                     'House - block of flats_house/bungalow',
                     'Education_currently a primary school pupil',
                     'Education_primary school',
                     'Education_secondary school',
                     'Education_college/bachelor degree',
                     'Education_masters degree',
                     'Education_doctorate degree',
                     'Number of siblings',
                     'Only child',
                     'overweight',
                     'underweight'] + ['Extraversion', 'Openness', 'Agreeableness', 'Emotional Stability', 'Conscientiousness']].corr()

sns.set(style='white')
cmap = sns.diverging_palette(220, 10, as_cmap=True)
mask = np.zeros_like(correlations, dtype=bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11,9))
sns.heatmap(correlations, mask=mask, cmap=cmap, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()

# %% [markdown]
# # Predicting Interests, Fears, and Happiness
# Now we'll attempt to predict interests, fears, and happiness using demographic and personality columns, and see which variables are the best predictors of each.

# %%
data.head()

# %%
# Drop unecessary columns and columns used in engineered features
fears_cols.remove('Ageing')
movie_cols.remove('Comedy')
movie_cols.remove('Romantic')
music_cols.remove('Techno, Trance')

data.drop(columns=['Gender', 'Age', 'Weight', 'Height', 'BMI', 'Age_category', 'Left - right handed', 'Village - town',
                   'House - block of flats', 'Smoking', 'Alcohol', 'Education', 
                   'Punctuality', 'Lying', 'Internet usage', 
                   'ID'] + cols_big5[cols_big5['Big 5 Trait'].notnull()]['Short'].to_list() + music_cols[2:] + movie_cols[1:] + interest_cols + fears_cols, inplace=True)
data.head()

# %%
# 70/30 train-test split
data = data.sample(frac=1).reset_index(drop=True)

train = data.iloc[:707]
test = data.iloc[707:]
train = pd.DataFrame(scaler.fit_transform(train), columns=data.columns)
test = pd.DataFrame(scaler.fit_transform(test), columns=data.columns)

train.head()

# %%
test.head()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFECV

lr = LinearRegression()
knn = KNeighborsRegressor()
rf = RandomForestRegressor(random_state=1)
xgboost_tree = xgb.XGBRegressor(random_state=1, verbosity=0, use_label_encoder=False)
xgboost_linear = xgb.XGBRegressor(random_state=1, verbosity=0, use_label_encoder=False, booster='gblinear')

targets = ['music_Rythmic', 'music_Traditional', 'music_Rock', 'music_Classic',
           'movies_Action', 'movies_Tales', 'movies_Thrilling',
           'fears_Nature & Environment', 'fears_Animals & Insects', 'Ageing',
           'interests_Humanities & Social Sciences', 'interests_STEM', 'interests_Art & Literature',
           'interests_Outdoor & Physical', 'interests_Lifestyle & Entertainment']

X = ['Openness', 'Extraversion', 'Conscientiousness', 'Emotional Stability', 'Agreeableness',
     'overweight', 'underweight', 'Gender_male', 'Gender_female', 'Age_category_18 and Under',
     'Age_category_19-24', 'Age_category_25-30', 
     'Village - town_city', 'Village - town_village',
     'House - block of flats_block of flats', 'House - block of flats_house/bungalow',
     'E x O', 'E x A', 'E x C', 'E x E', 'O x A', 'O x C', 'O x E', 'A x C', 'A x E', 'C x E'
    ]

def select_features(X, y, model):
    selector = RFECV(model, min_features_to_select=5, cv=5, scoring='neg_mean_absolute_error')
    selector.fit(X, y)
    
    best_columns = list(X.columns[selector.support_])
    return best_columns

def main_predictors(X, y, model):
#     best_cols = select_features(X, train[y], model)
    best_cols = X.columns
    model.fit(X[best_cols], train[y])
    
    scores = cross_val_score(model, X[best_cols], train[y], cv=5, scoring='neg_mean_absolute_error')
    train_scores = abs(np.mean(scores))
    print("Average Train MAE: ", round(train_scores, 2))
    
    scores = cross_val_score(model, test[best_cols], test[y], cv=5, scoring='neg_mean_absolute_error')
    test_scores = abs(np.mean(scores))
    print("Average Test MAE: ", round(test_scores, 2))
    
    fig, ax = plt.subplots(figsize=(8,10))
    importances = pd.Series(model.coef_, index=X[best_cols].columns).sort_values()
    importances[abs(importances) > 0.05].plot(kind='barh', color='orange')
    plt.show()

# %%
sns.set()
models = {'lr':lr, 'rf':rf, 'knn':knn, 'xgb_tree':xgboost_tree, 'xgb_linear':xgboost_linear}
target_model_scores = pd.DataFrame()

for t in targets:
    model_scores = pd.Series(dtype='float64')
    for m in models:
        scores = cross_val_score(models[m], train[X], train[t], cv=5, scoring='neg_mean_absolute_error')
        model_scores[m] = abs(np.mean(scores))
    target_model_scores[t] = model_scores

target_model_scores['Avg_score'] = target_model_scores.mean(axis=1)
target_model_scores['Avg_score'].sort_values(ascending=False).plot(kind='barh', title='Average MAE')
plt.show()

# %% [markdown]
# xgb_linear has the lowest average MAE across all of our targets, so we'll use it going forward.

# %% [markdown]
# ## Music
# ### Music: Rhythmic

# %%
main_predictors(train[X], 'music_Rythmic', xgboost_linear)

# %% [markdown]
# ### Music: Rock

# %%
main_predictors(train[X], 'music_Rock', xgboost_linear)

# %% [markdown]
# ### Music: Traditional

# %%
main_predictors(train[X], 'music_Traditional', xgboost_linear)

# %% [markdown]
# ### Music: Classic

# %%
main_predictors(train[X], 'music_Classic', xgboost_linear)

# %% [markdown]
# ### Music: Techno

# %%
main_predictors(train[X], 'Techno, Trance', xgboost_linear)

# %% [markdown]
# ## Movies
# ### Movies: Action

# %%
main_predictors(train[X], 'movies_Action', xgboost_linear)

# %% [markdown]
# ### Movies: Tales

# %%
main_predictors(train[X], 'movies_Tales', xgboost_linear)

# %% [markdown]
# ### Movies: Thrilling

# %%
main_predictors(train[X], 'movies_Thrilling', xgboost_linear)

# %% [markdown]
# ### Movies: Comedy

# %%
main_predictors(train[X], 'Comedy', xgboost_linear)

# %% [markdown]
# ### Movies: Romance

# %%
main_predictors(train[X], 'Romantic', xgboost_linear)

# %% [markdown]
# ## Interests
# ### Interests: Humanities & Social Sciences

# %%
main_predictors(train[X], 'interests_Humanities & Social Sciences', xgboost_linear)

# %% [markdown]
# ### Interests: STEM

# %%
main_predictors(train[X], 'interests_STEM', xgboost_linear)

# %% [markdown]
# ### Interests: Arts & Literature

# %%
main_predictors(train[X], 'interests_Art & Literature', xgboost_linear)

# %% [markdown]
# ### Interests: Outdoor & Physical

# %%
main_predictors(train[X], 'interests_Outdoor & Physical', xgboost_linear)

# %% [markdown]
# ### Interests: Lifestyle & Entertainment

# %%
main_predictors(train[X], 'interests_Lifestyle & Entertainment', xgboost_linear)

# %% [markdown]
# ## Fears
# ### Fears: Nature & Environment

# %%
main_predictors(train[X], 'fears_Nature & Environment', xgboost_linear)

# %% [markdown]
# ### Fears: Animals & Insects

# %%
main_predictors(train[X], 'fears_Animals & Insects', xgboost_linear)

# %% [markdown]
# ### Fears: Ageing

# %%
main_predictors(train[X], 'Ageing', xgboost_linear)

# %% [markdown]
# ## Happiness

# %%
main_predictors(train.drop(columns=['Happiness in life']), 'Happiness in life', xgboost_linear)

# %% [markdown]
# # Conclusion
# While this analysis is hypothesis-generating and not conclusive, we were able to establish that demographics, Big 5 personality traits, and interactions between the traits are significant predictors of a person's interests, fears, and happiness.
#
# In addition, we can see that having good energy levels, being social and valuing friends, listening to your parent's advice, and limiting internet usage are also associated with happiness.
#
# So be sure to exercise, get out and be social, and listen to your parents!
# Or if that doesn't work apparently you can always drop out of your PHD program and start drinking heavily😂
#
# Thanks for reading!
